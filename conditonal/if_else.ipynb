# %%
In = float(input("Enter a number"))
if In >= 2000:
    a= str(In-In*(15/100))
    print("your total balace after diccount is :"+a)
elif In >=1500 and 2000:
    b =str(In-In*(10/100))
    print("your total balace after diccount is :"+b)
elif In >=1000 and 1500:
    c=str(In-In*(7/100) )
    print("your total balace after diccount is :"+c)    
else :
    print("Your totaal is "+str(In))
# Out:
# your total balace after diccount is :1399.5
