# %%
class Market:
    def __init__(self, name, price, category):
        self.name = name
        self.price = price
        self.category = category 
        
    def get_info(self):
        print(f"The product is: {self.name}, Category: {self.category}")
        
    def amount(self):
        print(f"The price is: {self.price}")

# %%
market = (Market("Apple", 1.5, "Fruit"))
market.get_info()
market.amount()
# Out:
# The product is: Apple, Category: Fruit
# The price is: 1.5

# %%
class Product:
    def __init__(self, name, price, category):
        self.name = name
        self.category = category
        self.__price = price
    
    
    def get_price(self):
        return self.__price

    def set_price(self, new_price):
        if new_price > 0:
            self.__price = new_price
            print(f"Price updated to: {self.__price}")
        else:
            print("Error: Price must be greater than 0.")

    def get_info(self):
        print(f"Product: {self.name}, Category: {self.category}")

# %%
item = Product("Laptop", 1000, "Electronics")
item.set_price(1200) 
print(f"New Price: {item.get_price()}")
item.set_price(-50)
# Out:
# Price updated to: 1200
# New Price: 1200
# Error: Price must be greater than 0.
